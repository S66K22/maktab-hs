# %% [markdown]
# -   پیش بینی ﻣﺪت زﻣﺎﻧﯽ ﮐﻪ ﯾﮏ ﮐﺎرﺑﺮ ﯾﮏ وﯾﺪﯾﻮی آﻣﻮزﺷﯽ آﻧﻼﯾﻦ را ﻗﺒﻞ از ﺧﺮوج ﺗﻤﺎﺷﺎ ﻣﯽ ﮐﻨﺪ (ﺑﺮ ﺣﺴﺐ دﻗﯿﻘﻪ): **رگرسیون**
# -   تشخیص اﯾﻨﮑﻪ ﯾﮏ ﻧﻈﺮ ﺛﺒﺖ ﺷﺪه روی ﻣﺤﺼﻮل ﯾﮏ ﻓﺮوﺷﮕﺎه اﯾﻨﺘﺮﻧﺘﯽ «ﻣﺜﺒﺖ» اﺳﺖ ﯾﺎ «ﻣﻨﻔﯽ»:  **کلاسیفیکیشن**
# -   پیش ﺑﯿﻨﯽ ﻣﺼﺮف اﻧﺮژی روزاﻧﻪ ﯾﮏ ﺳﺎﺧﺘﻤﺎن اداری ﺑﺮ اﺳﺎس دﻣﺎ، ﺗﻌﺪاد ﮐﺎرﮐﻨﺎن و ﻣﺴﺎﺣﺖ: **رگرسیون**
# -   تشخیص اﯾﻨﮑﻪ آﯾﺎ ﯾﮏ ﺗﺮاﮐﻨﺶ ﮐﺎرت ﺑﺎﻧﮑﯽ ﻣﺸﮑﻮک ﺑﻪ ﮐﻼه ﺑﺮداری اﺳﺖ ﯾﺎ ﺧﯿﺮ: **کلاسیفیکیشن**
# -   پیش ﺑﯿﻨﯽ زﻣﺎن ﺗﻘﺮﯾﺒﯽ رﺳﯿﺪن ﯾﮏ ﻣﺮﺳﻮﻟﻪ ﭘﺴﺘﯽ ﺑﺮ اﺳﺎس ﻓﺎﺻﻠﻪ و روش ارﺳﺎل: **رگرسیون**
# -   ذسته ﺑﻨﺪی ﻣﺸﺘﺮﯾﺎن ﯾﮏ ﻓﺮوﺷﮕﺎه آﻧﻼﯾﻦ ﺑﻪ ﮔﺮوه ﻫﺎی رﻓﺘﺎری، ﺑﺪون داﺷﺘﻦ ﻫﯿﭻ ﺑﺮﭼﺴﺒﯽ از ﻗﺒﻞ: **کلاسترینگ**

# %% [markdown]
# | Scenario | Problem type | Suggested algorithm | Metric |
# |----------|--------------|---------------------|--------|
# | 1 | Regression | Linear Regression, KNN Regressor | $\text{MSE}$, $\text{MAE}$, $R^2$ |
# | 2 | Classification | Logistic Regression, Decision Tree Classifier, KNN Classifier | $\text{Accuracy}$, $\text{F1 Score}$, $\text{Precision}$, $\text{Recall}$, $\text{Confusion Matrix}$ |
# | 3 | Regression | Linear Regression, KNN Regressor | $\text{MSE}$, $\text{MAE}$, $R^2$ |
# | 4 | Classification | Logistic Regression, Decision Tree Classifier, KNN Classifier | $\text{Accuracy}$, $\text{F1 Score}$, $\text{Precision}$, $\text{Recall}$, $\text{Confusion Matrix}$ |
# | 5 | Regression | Linear Regression, KNN Regressor | $\text{MSE}$, $\text{MAE}$, $R^2$ |
# | 6 | Clustering | KMeans | - |

# %% [markdown]
# - بدون داشتن برچسب، امکان استفاده از این معیارها را نداریم.
# - داده‌ها غیر متوازن هستند و بایستی برای محاسبه‌ی دقیق وزن در معیارها دخیل گردد.
# - خروجی کلاسیفیکیشن چند مقدار محدود عددی صحیح است ولی در رگرسیون مقادیر محدود نیستند و می‌توانند صحیح یا اعشاری باشند. چنانچه بخواهیم در رگرسیون مانند کلاسیفیکیشن پیش بینی با برچسب دقیقا برابر باشد مدل به سمت اورفیت شدن و حفظ کردن نویزها می‌رود. یا به عبارتی بالا رفتن واریانس. برخی تسک‌ها ممکن هست رگرسیون یا کلاسیفیکشن تعبیر شوند. مانند پیش بینی مقدار هر پیکسل بین 0 و 255
